# %% [markdown]
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_cover_dark.svg" width="900" alt="1. Course Overview">

# %% [markdown]
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_unit1.svg" width="900" alt="1. Course Plan">

# %% [markdown]
# <font color="#0F6E56" size="6">**Why Learn Programming?**</font>
#
# > <font size="5">To trust, but verify, AI-generated outputs by yourself!</font>
#
# - <font size="5">Generative Artificial Intelligence (AI) can create code, but the code may contain errors or fail in specific situations.</font>
# - <font size="5">Basic programming knowledge allows us to test, verify, debug, and improve AI-generated code.</font>
# - <font size="5">Programming skills help us use AI as an assistant while maintaining human judgment, control, and problem-solving ability.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Course Introduction**</font>
#
# <font size="5">Python is one of the most widely used programming languages for data analysis, big data, and artificial intelligence. Even when generative AI tools generate code, basic programming knowledge is essential for understanding, testing, debugging, and verifying the results.</font>
#
# <font size="5">By the end of this course, you will be able to:</font>
# - <font size="5">Explain the basic syntax and core concepts of Python for data analysis and AI modeling.</font>
# - <font size="5">Apply these concepts to write and improve practical Python programs.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Overview of Course Content**</font>
#
# - <font size="5">This course covers the basic concepts and syntax of Python programming that are essential for understanding data analysis and AI, together with hands-on practice.</font>
#   - <font size="5">Students must therefore have access to a computer environment in which they can practice Python.</font>
#   - <font size="5">Taking this course or its assessments on a mobile device is **not recommended**.</font>
# - <font size="5">Programming may be required to solve midterm and final exam questions. **A separate computer for coding is required in addition to the device used to take the exam.**</font>
# - <font size="5">We use **Google Colab** for programming environment.</font>
#   - <font size="5">https://colab.google/</font>
# - <font size="5">The lecture notebooks are **executable** in Google Colab. We can learn the basic concepts and practice writing and running code all in one place.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Course Level**</font>
#
# - <font size="5">Introductory-level, first-year course.</font>
# - <font size="5">No prerequisites and no assumed background in computer science.</font>
# - <font size="5">This course is aimed at a level that any student who is willing to learn and practice Python can follow and complete the course.</font>
# - <font size="5">After completing this course, you can further explore *Python Data Analysis* , and *Big Data Analysis and AI Modeling* for the next step.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**References**</font>
#
# 1. <font size="5">Google Colab. https://colab.google/</font>
# 2. <font size="5">John V. Guttag, *Introduction to Computation and Programming Using Python: With Application to Computational Modeling and Understanding Data*, 3rd Edition, The MIT Press, Cambridge MA, 2021. ISBN 978-0-262-54236-4</font>
# 3. <font size="5">W3Schools, *Python Tutorial*. https://www.w3schools.com/python/</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Class Format**</font>
#
# - <font size="5">Lecture, discussion, hands-on practice, assignments, and problem solving.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Instructional Method**</font>
#
# - <font size="5">E-Learning content course.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Course Operation Strategy**</font>
#
# - <font size="5">Delivered through video lectures and lecture notes.</font>
# - <font size="5">Hands-on practice in Google Colab, where students write and run code directly without frustrating environment setting process.</font>
# - <font size="5">Through the course, pause and excercise yourself everytime I mention '**Pause a minute**'.</font>
# - <font size="5">Regular guidance on assignments, exams, discussions, and announcements.</font>
# - <font size="5">Monitoring class Q&As, participation and attendance status.</font>
# - <font size="5">The course board will be used to notify students of important announcements and discuss among the students.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Grading**</font>
#
# | <font size="5">Component</font> | <font size="5">Weight</font> |
# |---|---|
# | <font size="5">Attendance</font> | <font size="5">10%</font> |
# | <font size="5">Midterm exam</font> | <font size="5">20%</font> |
# | <font size="5">Final exam</font> | <font size="5">20%</font> |
# | <font size="5">Assignments</font> | <font size="5">40% (two assignments, 20% each)</font> |
# | <font size="5">Participation</font> | <font size="5">10%</font> |
# | <font size="5">**Total**</font> | <font size="5">**100%**</font> |
#
# - <font size="5">Grades are determined on a relative basis.</font>
# - <font size="5">Automatic F: attendance below three quarters of the course, absence from both the midterm and the final exam, or a total score of 10 points or below.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Weekly Schedule**</font>
#
# | <font size="5">Week</font> | <font size="5">Topic</font> |
# |------|-------|
# | <font size="5">1</font> | <font size="5">Course Overview</font> |
# | <font size="5">2</font> | <font size="5">Data Types and Variables</font> |
# | <font size="5">3</font> | <font size="5">Lists and Tuples</font> |
# | <font size="5">4</font> | <font size="5">Dictionaries and Sets</font> |
# | <font size="5">5</font> | <font size="5">Conditional Statements</font> |
# | <font size="5">6</font> | <font size="5">Loops</font> |
# | <font size="5">7</font> | <font size="5">Functions</font> |
# | <font size="5">**8**</font> | <font size="5">**Midterm Exam**</font> |
# | <font size="5">9</font> | <font size="5">Strings and Regular Expressions</font> |
# | <font size="5">10</font> | <font size="5">Modules and Packages</font> |
# | <font size="5">11</font> | <font size="5">File I/O and Exception Handling</font> |
# | <font size="5">12</font> | <font size="5">Classes</font> |
# | <font size="5">13</font> | <font size="5">Advanced Topics</font> |
# | <font size="5">14</font> | <font size="5">Introduction to Data Analysis Libraries</font> |
# | <font size="5">**15**</font> | <font size="5">**Final Exam**</font> |

# %% [markdown]
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_unit2.svg" width="900" alt="2. Introduction to Python and Colab">

# %% [markdown]
# <font color="#0F6E56" size="6">**Week Learning Objectives**</font>
#
# <font size="5">By the end of this week, you will be able to:</font>
#
# 1. <font size="5">Explain why Python is the dominant language in data analysis and artificial intelligence.</font>
# 2. <font size="5">Identify the equipment required for coursework and exams.</font>
# 3. <font size="5">Compare Jupyter Notebook and Google Colab, and select Colab as the practice environment for this course.</font>
# 4. <font size="5">Create a Colab notebook and write, run, and comment a first Python program that declares variables and performs arithmetic.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Why We Use Python for Data Analysis and AI Modeling**</font>
#
# - <font size="5">A rich library ecosystem:</font>
#   - <font size="5">**NumPy**: high-performance numerical computing</font>
#   - <font size="5">**Pandas**: data processing and analysis</font>
#   - <font size="5">**Matplotlib / Seaborn**: data visualization</font>
# - <font size="5">Concise, readable syntax that supports fast development.</font>
# - <font size="5">Runs as an interactive mode, which is suitable for processing large volumes of data.</font>
# - <font size="5">High compatibility with machine learning and deep learning frameworks.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Why Python is Popular**</font>
#
# - <font size="5">**Readable Syntax**: concise and intuitive</font>
#   - <font size="5">eg., A variable named as 'total_price' rather than 'x'.</font>
# - <font size="5">**Versatility**: used in web development, data analysis, artificial intelligence, game development, and many other fields</font>
# - <font size="5">**Strong Community**: a vast set of open-source libraries and active support</font>
# - <font size="5">**High Productivity**: students accomplish a great deal with little code</font>
# - <font size="5">**Industry Demand**: employers ask for Python across many roles, including data scientist and software developer</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**`Note`  How to check the popularity of a programming language**</font>
#
# - <font size="5">**TIOBE Index**</font>
#   - <font size="5">https://www.tiobe.com/tiobe-index/</font>
#   - <font size="5">A widely known indicator of programming language popularity.</font>
#   - <font size="5">Limitation: it measures how often a language is mentioned, not how much it is actually used.</font>
# - <font size="5">**PYPL (PopularitY of Programming Language)**</font>
#   - <font size="5">https://pypl.github.io/PYPL.html</font>
#   - <font size="5">An indicator based on Google Trends and search data.</font>
#   - <font size="5">Limitation: it measures search frequency, not actual usage.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Google Colab**</font>
#
# - <font size="5">https://colab.google/</font>
# - <font size="5">A **hosted** Jupyter Notebook service that allows users to create, open, and run `.ipynb` *notebook*  files in a web browser.</font>
# - <font size="5">A Google account is required.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Why We Use Google Colab**</font>
#
# - <font size="5">With only a Google account, students get a ready-made environment for data analysis and AI modeling, with no installation.</font>
# - <font size="5">Students can access computing resources including GPUs and TPUs, free of charge (or on a paid plan).</font>
# - <font size="5">Colab suits machine learning, data analysis, and education.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Jupyter Notebook vs. Colab**</font>
#
# | <font size="5">Feature</font> | <font size="5">Jupyter Notebook</font> | <font size="5">Colab</font> |
# |------|------------------|-------|
# | <font size="5">Installation</font> | <font size="5">Required</font> | <font size="5">Not required</font> |
# | <font size="5">Internet connection</font> | <font size="5">Works offline</font> | <font size="5">Required</font> |
# | <font size="5">Computing resources</font> | <font size="5">Uses local machine resources</font> | <font size="5">GPU and TPU available, free (or paid)</font> |
# | <font size="5">Environment setup</font> | <font size="5">Version management required</font> | <font size="5">Not required by default</font> |
#
# - <font size="5">Colab is a hosted Jupyter Notebook service.</font>
# - <font size="5">Jupyter Notebook runs locally and is available after installing Anaconda.</font>
#   - <font size="5">https://www.anaconda.com/</font>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_unit3.svg" width="900" alt="3. Getting Started with Colab">

# %% [markdown]
# <font color="#0F6E56" size="6">**Create a Google Account (If You Do Not Have One)**</font>
#
# - <font size="5">Go to https://accounts.google.com</font>
# - <font size="5">Click `Create account` and register for a new account.</font>
#
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_CreateaGoogleAccount.png" width="900" alt="Google sign-in page with the Create account button">

# %% [markdown]
# <font color="#0F6E56" size="6">**Open Google Colab Website**</font>
#
# - <font size="5">https://colab.google/</font>
#
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_colab_beforelogin.png" width="900" alt="Google Colab site">

# %% [markdown]
# <font color="#0F6E56" size="6">**Create or Open a Notebook**</font>
#
# - <font size="5">Click the `+ New notebook` button to start a new notebook in Colab.</font>
#
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_new-notebook.png" width="900" alt="Google Colab site">
#
# - <font size="5">Click `Upload` menu and click `Browse` button to select the notebook file you want to upload, e.g., 'AIProgrammingFundamentals_Week01.ipynb'.</font>
#
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_open-notebook.png" width="900" alt="Google Colab site">

# %% [markdown]
# <font color="#0F6E56" size="6">**Key Features of Google Colab**</font>
#
# | <font size="5">**Feature**</font> | <font size="5">**What it does**</font> |
# |:---:|---|
# | <font size="5">**Code Cell**</font><br><br> | <font size="5">Write and run Python code</font> |
# | <font size="5">**Text Cell**</font><br><br> | <font size="5">Write documentation in Markdown format</font> |
# | <font size="5">**Change Runtime Type**</font><br><br> | <font size="5">Select CPU, GPU, or TPU according to the task</font> |
# | <font size="5">**File Upload / Download**</font><br><br> | <font size="5">Upload local files, or download files created in Colab</font> |

# %% [markdown]
# <font color="#0F6E56" size="6">**Create a New Cell**</font>
#
# - <font size="5">Press `Ctrl`+`M` first so that Colab treats the next key as a command rather than text.</font>
# - <font size="5">Press `A` to insert a new code cell **above** the selected cell.</font>
# - <font size="5">Press `B` to insert a new code cell **below** the selected cell.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Write Your First Code: Hello, Colab!**</font>
#
# - <font size="5">**How to run a cell:**</font>
#   - <font size="5">Click the run button on the left of the cell.</font>
#   - <font size="5">Press `Shift` + `Enter` after pressing `Ctrl`+`M` to use the shortcut.</font>
# - <font size="5">**Result: `Hello, Colab!` is printed below the cell**.</font>

# %%
print('Hello, Colab!')
# Out:
# Hello, Colab!

# %% [markdown]
# <font color="#0F6E56" size="6">**Let's Practice**</font>
#
# <font size="5">Add a new code cell below and write code that displays `Python rocks!` without quotation marks in the output.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Declaring and Using Variables**</font>

# %%
a = 5
b = 'Python'

print(a, b)

# %% [markdown]
# <font color="#0F6E56" size="6">**Simple Arithmetic Operations**</font>

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)

# %% [markdown]
# <font color="#0F6E56" size="6">**Automatic Output of a Code Cell**</font>
#
# - <font size="5">The result of the **last line** of a code cell is displayed automatically, without a call to `print()`.</font>

# %%
a = 10
b = 3

a + b

# %% [markdown]
# - <font size="5">When a cell contains several expressions, only the last one is displayed automatically.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Using Text Cells**</font>
#
# - <font size="5">Add a text cell below this cell.</font>
# - <font size="5">Use Markdown syntax to write `Basic Arithmetic` as a level-three heading.</font>

# %% [markdown]
# <font color="#0F6E56" size="6">**Writing Comments Inside Code Cells**</font>
#
# - <font size="5">Use `#` to start a comment.</font>
# - <font size="5">Shortcut: press `Ctrl` + `/` to comment out the selected lines of code.</font>

# %%
# Arithmetic Example
a = 10
b = 3

print(a + b)
# print(a - b)
# print(a * b)
print(a / b)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_unit4.svg" width="900" alt="4. Key Takeaways">

# %% [markdown]
# <font color="#0F6E56" size="6">**Summary**</font>
#
#
# <img src="https://raw.githubusercontent.com/youngah-shin/youngashin.github.io/main/img/w01_summary_qa.svg" width="900" alt="4. Key Terms">

# %% [markdown]
# <font color="#0F6E56" size="6">**Key Terms**</font>
#
#
# <font size="5">`Python` `Google Colab` `Jupyter Notebook` `code cell` `text cell` `runtime` `variable` `comment` `automatic output`</font>
